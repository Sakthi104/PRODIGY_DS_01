# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("population_csv.csv")

# %%
df.head(7)
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date                   28-06-2024
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
# 5                  Afghanistan                          AFG
# 6   Africa Western and Central                          AFW
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# 2     Indicator Name  Indicator Code       1960.0       1961.0       1962.0
# 3  Population, total     SP.POP.TOTL      54608.0      55811.0      56682.0
# 4  Population, total     SP.POP.TOTL  130692579.0  134169237.0  137835590.0
# ...

# %%
df.dropna(inplace=True)

# %%
df.columns=df.iloc[0]

# %%
df=df[1:]

# %%
df.reset_index(inplace=True)
df.drop(['index','Country Name'	,'Country Code'	,'Indicator Name',	'Indicator Code'	],axis=1,inplace=True)

# %%
df
# Out:
# 2         1960.0       1961.0       1962.0       1963.0       1964.0  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# 1    130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2      8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3     97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4      5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# ..           ...          ...          ...          ...          ...
# 259     990150.0    1014211.0    1038618.0    1063175.0    1087700.0
# 260    5542459.0    5646668.0    5753386.0    5860197.0    5973803.0
# 261   16520441.0   16989464.0   17503133.0   18042215.0   18603097.0
# 262    3119430.0    3219451.0    3323427.0    3431381.0    3542764.0
# 263    3806310.0    3925952.0    4049778.0    4177931.0    4310332.0
#
# 2         1965.0       1966.0       1967.0       1968.0       1969.0  ...  \
# ...

# %%
sum=pd.DataFrame(df.sum(axis=0))
sum=pd.DataFrame(sum.floordiv(1000000000))

# %%
sum.columns=['Population']

# %%
sum.index.values
# Out:
# array([1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0,
#        1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0,
#        1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0,
#        1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0,
#        1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0,
#        2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0,
#        2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0,
#        2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0, 2023.0],
#       dtype=object)

# %%
sum
# Out:
#         Population
# 2
# 1960.0        30.0
# 1961.0        30.0
# 1962.0        31.0
# 1963.0        32.0
# 1964.0        32.0
# ...            ...
# 2019.0        83.0
# 2020.0        84.0
# 2021.0        84.0
# 2022.0        85.0
# 2023.0        86.0
#
# [64 rows x 1 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(sum.index,sum['Population'].values,label=['Year', 'Population'])
plt.show()
